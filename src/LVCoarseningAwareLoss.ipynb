# %% [markdown]
# # Local Variation + GNN with Coarsening aware Loss

# %% [markdown]
# ## Import

# %%
import os
import sys
import random
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# pygsp
from pygsp import graphs

# scipy
import scipy as sp

# torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# torch geometric
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import to_undirected

# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics.pairwise import cosine_similarity


# graph coarsening - Loukas 2020
from graphcoarsening.graph_coarsening.coarsening_utils import *
from graphcoarsening.graph_coarsening.graph_utils import *

# datasets
data_path = os.path.abspath(os.path.join("..", "data"))
if data_path not in sys.path:
    sys.path.append(data_path)
from cora.load_cora import load_cora_dataset

# plot
import matplotlib.pyplot as plt

# utils
from utils.split_dataset import *
from utils.visualization import *


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

torch.manual_seed(1)
np.random.seed(1)
# Out:
# Using device: cpu

# %% [markdown]
# ## Global data
#
# - `NODE_IDS`: list of nodes ids
# - `FEATURES`: (N x D) matrix of features for each node
# - `LABELS`: (N) list of true labels for each node
# - `EDGES_IDX`: (M, 2) matrix of edges
# - `IDX_MAP`: dict mapping original node IDs to index

# %%
# load dataset and gloa
NODE_IDS, FEATURES, LABELS, EDGES_IDX, IDX_MAP = load_cora_dataset(log_info=False)
LABELS_ENCODED = LabelEncoder().fit_transform(LABELS)

# %% [markdown]
# ## General functions

# %% [markdown]
# ### Create PyGSP Graph

# %%
def create_pygsp_graph(edges, num_nodes) -> graphs.Graph: 
    # adjacency matrix
    adj_matrix = sp.sparse.coo_matrix(
        (np.ones(len(edges)),
        (edges[:, 0], edges[:, 1])), 
        shape=(num_nodes, num_nodes)
    )
    adj_matrix = adj_matrix + adj_matrix.T
    adj_matrix.data = np.ones(len(adj_matrix.data))

    # pygsp graph
    G = graphs.Graph(adj_matrix)
    G.compute_laplacian()
    G.set_coordinates()
    
    return G

# %% [markdown]
# ### Apply coarsening by Loukas

# %%
def apply_graph_coarsening(G: graphs.Graph, X=None, method='variation_neighborhoods', ratio=0.5, K=3, similarity_threshold=0.65, log_info=False):
    """
    Output:
      - C: coarsening matrix (n, N)
      - Gc: coarsened graph (n, n)
      - Call: all coarsened graphs (levels, n_l, N)
      - Gall: all original graphs (levels, n_l, n_l)
    """
    
    available_methods = ['variation_neighborhoods', 'variation_edges', 'heavy_edge', 'algebraic_JC', 'kron'] 
    if method not in available_methods:
        raise ValueError(f"Unknown coarsening method: {method}. Method must be one of {available_methods}.")
    
    C, Gc, Call, Gall = coarsen(G, X=X, K=K, method=method, r=ratio, similarity_threshold=similarity_threshold)

    if log_info:
        print(f"Coarsening: {method} ", end='')
        print(f"({G.N} n, {G.Ne} e) -> ({Gc.N} n, {Gc.Ne} e); ")
    
    return C, Gc, Call, Gall

# %% [markdown]
# ### Get coarsened data from Coarsening matrix C

# %%
def get_coarsened_edges_and_features(C: list, Gc: graphs.Graph, features):
    """
    Coarsen edges and features based on the coarsening matrix C;
    the feature matrix (N x D) is made by summing up features from nodes that are coarsened into the same supernode.

    Output:
      - Gc: coarsened edges index (num_edges, 2)
      - features_coarsened: coarsened features (num_nodes_coarsened, num_features)
    """

    idx_map = {} # map fine node -> coarse node 
    for supernode, node in zip(*C.nonzero()):
        idx_map[node] = supernode
        
    # features coarsened
    features_coarsened = C @ features
    
    # edges coarsened
    edges_idx_coarsened = np.array(Gc.get_edge_list()[:2]).T

    return edges_idx_coarsened, features_coarsened


def get_coarsened_edges_features_labels(C: list, Gc: graphs.Graph, features, labels, priority_label=0):
    """
    Coarsen edges and features based on the coarsening matrix C;
    the feature matrix (N x D) is made by summing up features from nodes that are coarsened into the same supernode.

    Output:
      - edges_idx_coarsened: coarsened edges index (num_edges, 2)
      - features_coarsened: coarsened features (num_nodes_coarsened, num_features)
      - labels_coarsened: coarsened labels (num_nodes_coarsened,)
    """

    idx_map = {} # map fine node -> coarse node 
    for supernode, node in zip(*C.nonzero()):
        idx_map[node] = supernode
        
    # features coarsened
    features_coarsened = C @ features

    # edges coarsened
    edges_idx_coarsened = np.array(Gc.get_edge_list()[:2]).T

    # labels coarsened
    num_classes = len(np.unique(labels))
    all_labels = np.zeros((C.shape[0], num_classes), dtype=np.float32)
    for supernode, node in zip(*C.nonzero()):
        all_labels[supernode, labels[node]] += 1

    labels_coarsened = np.zeros(C.shape[0], dtype=np.int64)
    for supernode in range(C.shape[0]):
        mx = np.argmax(all_labels[supernode])
        priority_count = all_labels[supernode, priority_label]
        if priority_count >= mx:
            labels_coarsened[supernode] = priority_label
        else: 
            labels_coarsened[supernode] = mx

    return edges_idx_coarsened, features_coarsened, labels_coarsened

# %% [markdown]
# ## GNN

# %% [markdown]
# ### model and training function

# %%
class GCN(nn.Module):
    def __init__(self, nfeat, nhid, nclass, dropout=.5):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(nfeat, nhid)
        self.conv2 = GCNConv(nhid, nclass)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)
    
    def get_embeddings(self, x, edge_index):
        x = x.to(next(self.parameters()).device)  # send x to the model's device
        edge_index = edge_index.to(x.device) 
        x = F.relu(self.conv1(x, edge_index))
        return x

class CoarseningAwareLoss(nn.Module):
    def __init__(self, coarse_weight: float = 1.0):
        """
        Args:
          coarse_weight: weight for the coarsening loss term.
        """
        super().__init__()
        self.coarse_weight = coarse_weight
        self.class_loss = nn.NLLLoss()


    def forward(self,
                output: torch.Tensor,
                embeddings: torch.Tensor,
                labels: torch.Tensor,
                coarsening_matrix: torch.Tensor,
                train_idx: torch.Tensor):
        """
        output: [N, C] log-probabilities (log_softmax).
        embeddings: [N, D] raw features from model.get_embeddings().
        labels: [N] ground-truth class labels.
        coarsening_matrix: [Nc, N] coarsening matrix.
        train_idx: indices of coarsened nodes used for classification loss.
        """
        device = output.device
        N = embeddings.shape[0]

        # 1. Classification loss
        loss_cls = self.class_loss(output[train_idx], labels[train_idx])

        # 2. Embedding normalization
        embeddings_norm = F.normalize(embeddings, p=2, dim=1)

        with torch.no_grad():
            supernodes = torch.zeros(N, dtype=torch.long, device=device)
            for i, j in zip(*coarsening_matrix.nonzero()):
                supernodes[j] = i


        loss_coarse = torch.tensor(0.0, device=device)
        count = 0

        n_sample = 500
        for _ in range(n_sample):
            i, j = random.sample(range(N), 2)
            emb_i = embeddings_norm[i]
            emb_j = embeddings_norm[j]
            sim = F.cosine_similarity(emb_i.unsqueeze(0), emb_j.unsqueeze(0)).squeeze()

            if supernodes[i] == supernodes[j]:
                loss_coarse += 1 - sim
            else:
                loss_coarse += sim
            count += 1

        loss_coarse = loss_coarse / count if count > 0 else torch.tensor(0.0, device=device)
        return loss_cls + self.coarse_weight * loss_coarse

# %%
def create_pyg_data(features, edges_idx, labels) -> Data:
    x = torch.FloatTensor(features.astype(np.float32))
    y = torch.LongTensor(labels)
    edge_index = torch.LongTensor(edges_idx.T)  # expects (2, num_edges)
    edge_index = to_undirected(edge_index)
        
    return Data(x=x, edge_index=edge_index, y=y)

def train_gnn_1_epoch(model: nn.Module, optimizer: optim.Optimizer, criterion: nn.Module, data: Data, embeddings, coarsening_matrix, train_idx: list, val_idx: list):
    """
    Output:
        - train_loss
        - val_loss
        - val_accuracy
    """
    
    data = data.to(next(model.parameters()).device)
    
    model.train()
    optimizer.zero_grad()
    
    output = model(data.x, data.edge_index)
    # embeddings = model.get_embeddings(data.x, data.edge_index)

    # train
    loss = criterion(output, embeddings, data.y, coarsening_matrix, train_idx)
    loss.backward()
    optimizer.step()
    
    # validate
    model.eval()
    with torch.no_grad():
        output = model(data.x, data.edge_index)
        # embeddings = model.get_embeddings(data.x, data.edge_index)

        loss_val = criterion(output, embeddings, data.y, coarsening_matrix, val_idx)
        pred_val = output[val_idx].max(1)[1]
        acc_val = accuracy_score(data.y[val_idx].cpu().numpy(), pred_val.cpu().numpy())

    
    return loss.item(), loss_val.item(), acc_val

def evaluate_model(model: nn.Module, data: Data, test_idx, log_info=True):
    """Evaluate the model on test set."""
    model.eval()
    data = data.to(next(model.parameters()).device)
    
    with torch.no_grad():
        output = model(data.x, data.edge_index)
        pred_test = output[test_idx].max(1)[1]
        acc_test = accuracy_score(data.y[test_idx].cpu().numpy(), pred_test.cpu().numpy())
        
        if log_info:
            print(f'\nTest Accuracy: {acc_test:.4f}')
            print('\nClassification Report:')
            print(classification_report(
                data.y[test_idx].cpu().numpy(), pred_test.cpu().numpy())
            )

    return acc_test, pred_test

# %% [markdown]
# ## `Coarsen - GNN and Loss`
#
# **workflow:**
# ```latex
# 1. Train GNN on full graph to initialize weights
# 2. Iterate:
#     1. generate embeddings of all nodes from GNN(A, X)
#     2. coarsen the graph using embeddings as node features
#     3. Train GNN on coarsened nodes
#         - loss is coarsening-aware
# ```

# %%
def train_GNN_coarsening_aware_loss(epochs: int, lr=0.01, wd=5e-4, method='variation_neighborhoods', ratio=0.8, similarity_threshold=0.65):
    # model
    nfeat = FEATURES.shape[1]  # 1433
    nhid = 128
    nclass = len(np.unique(LABELS_ENCODED))  # 7
    dropout = 0.1
    model = GCN(nfeat=nfeat, nhid=nhid, nclass=nclass, dropout=dropout).to(device)

    # criterion
    criterion = CoarseningAwareLoss()

    # train data
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
    data = create_pyg_data(FEATURES, EDGES_IDX, LABELS_ENCODED)

    x, ycrs, yfine, ylosst, ylossv, valacc = [], [], [], [], [], []
    for epoch in range(epochs):

        print(f"Iteration {epoch + 1:02d}/{epochs}")

        # get embeddings from the GNN
        embeddings = model.get_embeddings(data.x, data.edge_index)

        # coarsen the graph using embeddings as features
        G = create_pygsp_graph(EDGES_IDX, data.num_nodes)
        C, Gc, Call, Gall = apply_graph_coarsening(
            G, X=embeddings, method=method, ratio=ratio, K=50, similarity_threshold=similarity_threshold, log_info=True
        )

        # train the GNN on the coarsened graph
        edges_idx_c, feat_c, labels_C = get_coarsened_edges_features_labels(
            C, Gc, FEATURES, LABELS_ENCODED, priority_label=0
        )
        data_c = create_pyg_data(feat_c, edges_idx_c, labels_C)
        train_idx_c, val_idx_c, test_idx_c = create_train_val_test_split(data_c.num_nodes)
        train_idx_c = torch.LongTensor(train_idx_c).to(device)
        val_idx_c = torch.LongTensor(val_idx_c).to(device)
        test_idx_c = torch.LongTensor(test_idx_c).to(device)
        train_loss, validation_loss, validation_accuracy = train_gnn_1_epoch(
            model, optimizer, criterion, data_c, embeddings, C, train_idx_c, val_idx_c
        )

        print(f"Train Loss: {train_loss:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}")

        # evaluate the model on the coarsened graph
        acc_test_c, pred_test_c = evaluate_model(model, data_c, test_idx_c, log_info=False)

        # evaluate on original (fine) graph
        pred_fine = np.array([-1 for _ in range(NODE_IDS.shape[0])], dtype=np.int64)
        tot = 0
        for idx in range(len(test_idx_c)):
            test_supernode = test_idx_c[idx]
            for fine_node in C.getrow(test_supernode).nonzero()[1]:
                pred_fine[fine_node] = pred_test_c[idx]
                tot += 1

        sm = sum(pred_fine == LABELS_ENCODED)
        accuracy_fine = sm / tot

        print(f"Test - coarse accuracy: {acc_test_c:.4f}, fine accuracy: {accuracy_fine:.4f}\n")

        # ploting data
        x.append(epoch + 1)
        ycrs.append(acc_test_c)
        yfine.append(accuracy_fine)
        ylosst.append(train_loss)
        ylossv.append(validation_loss)
        valacc.append(validation_accuracy)

    np.save(f'saves/data_gnn_CoarseningAwareLoss_threshold_{similarity_threshold*100:.0f}_{method}_ratio_{ratio*100:.0f}.npy', {
        'x': x,
        'ycrs': ycrs,
        'yfine': yfine,
        'ylosst': ylosst,
        'ylossv': ylossv,
        'valacc': valacc,
        'description': f'Data obtained using: {ratio=}, {method=}, {similarity_threshold=}, CoarseningAwareLoss()'
        })

# %% [markdown]
# ## generate data

# %%
# from itertools import product

# epochs = 50
# methods = ['variation_neighborhoods', 'variation_edges']
# ratios = [.5, .8, .9, .95]
# thresholds = [0.50, 0.65, 0.75, 0.85]

# for method, ratio, threshold in product(methods, ratios, thresholds):
#     train_GNN_coarsening_aware_loss(epochs=epochs, method=method, ratio=ratio, similarity_threshold=threshold)
# Out:
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2863 e);
# Train Loss: 2.3540, Validation Loss: 2.1690, Validation Accuracy: 0.4667
# Test - coarse accuracy: 0.4853, fine accuracy: 0.4611
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2864 e);
# Train Loss: 2.2345, Validation Loss: 2.1223, Validation Accuracy: 0.7296
# Test - coarse accuracy: 0.7279, fine accuracy: 0.7358
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2870 e);
# Train Loss: 1.9988, Validation Loss: 1.9096, Validation Accuracy: 0.7852
# Test - coarse accuracy: 0.7831, fine accuracy: 0.7808
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2832 e);
# Train Loss: 1.8400, Validation Loss: 1.7090, Validation Accuracy: 0.7491
# Test - coarse accuracy: 0.7601, fine accuracy: 0.6941
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2864 e);
# Train Loss: 1.6789, Validation Loss: 1.4689, Validation Accuracy: 0.7889
# Test - coarse accuracy: 0.7794, fine accuracy: 0.7618
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2867 e);
# Train Loss: 1.5330, Validation Loss: 1.4181, Validation Accuracy: 0.7630
# Test - coarse accuracy: 0.7500, fine accuracy: 0.7385
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2864 e);
# Train Loss: 1.3726, Validation Loss: 1.2253, Validation Accuracy: 0.8296
# Test - coarse accuracy: 0.8125, fine accuracy: 0.7746
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2862 e);
# Train Loss: 1.2283, Validation Loss: 1.1341, Validation Accuracy: 0.7926
# Test - coarse accuracy: 0.8676, fine accuracy: 0.8472
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2876 e);
# Train Loss: 1.1387, Validation Loss: 1.0406, Validation Accuracy: 0.8148
# Test - coarse accuracy: 0.8272, fine accuracy: 0.7842
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2814 e);
# Train Loss: 1.0416, Validation Loss: 0.9485, Validation Accuracy: 0.8593
# Test - coarse accuracy: 0.8640, fine accuracy: 0.8853
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2862 e);
# Train Loss: 0.9703, Validation Loss: 0.8618, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.8824, fine accuracy: 0.8776
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2898 e);
# Train Loss: 0.8994, Validation Loss: 0.8170, Validation Accuracy: 0.8856
# Test - coarse accuracy: 0.8635, fine accuracy: 0.8319
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2810 e);
# Train Loss: 0.8338, Validation Loss: 0.8141, Validation Accuracy: 0.8635
# Test - coarse accuracy: 0.8930, fine accuracy: 0.8622
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2878 e);
# Train Loss: 0.7641, Validation Loss: 0.8440, Validation Accuracy: 0.8708
# Test - coarse accuracy: 0.8782, fine accuracy: 0.8388
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2975 e);
# Train Loss: 0.7923, Validation Loss: 0.6676, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.8824, fine accuracy: 0.8368
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2874 e);
# Train Loss: 0.7349, Validation Loss: 0.6404, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8602
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2864 e);
# Train Loss: 0.6865, Validation Loss: 0.6544, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8645
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2870 e);
# Train Loss: 0.6524, Validation Loss: 0.6556, Validation Accuracy: 0.9041
# Test - coarse accuracy: 0.8893, fine accuracy: 0.8663
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2862 e);
# Train Loss: 0.6357, Validation Loss: 0.6607, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8657
#
# Iteration 20/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2814 e);
# Train Loss: 0.6395, Validation Loss: 0.5311, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.8676, fine accuracy: 0.8563
#
# Iteration 21/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2816 e);
# Train Loss: 0.5991, Validation Loss: 0.6569, Validation Accuracy: 0.8741
# Test - coarse accuracy: 0.9338, fine accuracy: 0.8973
#
# Iteration 22/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2863 e);
# Train Loss: 0.5690, Validation Loss: 0.5886, Validation Accuracy: 0.8815
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8728
#
# Iteration 23/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2940 e);
# Train Loss: 0.5669, Validation Loss: 0.6032, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.9044, fine accuracy: 0.8794
#
# Iteration 24/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2865 e);
# Train Loss: 0.5512, Validation Loss: 0.5683, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8414
#
# Iteration 25/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2806 e);
# Train Loss: 0.5376, Validation Loss: 0.5507, Validation Accuracy: 0.8889
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8707
#
# Iteration 26/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2886 e);
# Train Loss: 0.5196, Validation Loss: 0.5409, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.9228, fine accuracy: 0.8793
#
# Iteration 27/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2808 e);
# Train Loss: 0.5095, Validation Loss: 0.5153, Validation Accuracy: 0.8889
# Test - coarse accuracy: 0.9301, fine accuracy: 0.8784
#
# Iteration 28/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2801 e);
# Train Loss: 0.5043, Validation Loss: 0.4443, Validation Accuracy: 0.9407
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8345
#
# Iteration 29/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2876 e);
# Train Loss: 0.5364, Validation Loss: 0.4848, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8459
#
# Iteration 30/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2809 e);
# Train Loss: 0.4960, Validation Loss: 0.4433, Validation Accuracy: 0.9370
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8524
#
# Iteration 31/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2804 e);
# Train Loss: 0.4561, Validation Loss: 0.5185, Validation Accuracy: 0.8926
# Test - coarse accuracy: 0.9228, fine accuracy: 0.8668
#
# Iteration 32/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2800 e);
# Train Loss: 0.4698, Validation Loss: 0.4705, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9191, fine accuracy: 0.8577
#
# Iteration 33/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2885 e);
# Train Loss: 0.5035, Validation Loss: 0.4225, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.8897, fine accuracy: 0.8646
#
# Iteration 34/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2808 e);
# Train Loss: 0.4208, Validation Loss: 0.5134, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8485
#
# Iteration 35/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2809 e);
# Train Loss: 0.4566, Validation Loss: 0.4797, Validation Accuracy: 0.8963
# Test - coarse accuracy: 0.9449, fine accuracy: 0.8817
#
# Iteration 36/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2938 e);
# Train Loss: 0.4521, Validation Loss: 0.4831, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9191, fine accuracy: 0.8930
#
# Iteration 37/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2926 e);
# Train Loss: 0.4496, Validation Loss: 0.4788, Validation Accuracy: 0.9151
# Test - coarse accuracy: 0.9336, fine accuracy: 0.9122
#
# Iteration 38/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2891 e);
# Train Loss: 0.4730, Validation Loss: 0.4137, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9338, fine accuracy: 0.8945
#
# Iteration 39/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2806 e);
# Train Loss: 0.4202, Validation Loss: 0.3968, Validation Accuracy: 0.9148
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8769
#
# Iteration 40/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2801 e);
# Train Loss: 0.4103, Validation Loss: 0.4358, Validation Accuracy: 0.9259
# Test - coarse accuracy: 0.9375, fine accuracy: 0.8636
#
# Iteration 41/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2812 e);
# Train Loss: 0.4184, Validation Loss: 0.4281, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9076
#
# Iteration 42/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2884 e);
# Train Loss: 0.4504, Validation Loss: 0.3766, Validation Accuracy: 0.9519
# Test - coarse accuracy: 0.9375, fine accuracy: 0.9369
#
# Iteration 43/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2849 e);
# Train Loss: 0.3880, Validation Loss: 0.4808, Validation Accuracy: 0.9148
# Test - coarse accuracy: 0.9375, fine accuracy: 0.8930
#
# Iteration 44/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2801 e);
# Train Loss: 0.3532, Validation Loss: 0.4977, Validation Accuracy: 0.8741
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9182
#
# Iteration 45/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2855 e);
# Train Loss: 0.4044, Validation Loss: 0.4164, Validation Accuracy: 0.9262
# Test - coarse accuracy: 0.9410, fine accuracy: 0.9196
#
# Iteration 46/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2849 e);
# Train Loss: 0.4093, Validation Loss: 0.3579, Validation Accuracy: 0.9407
# Test - coarse accuracy: 0.9338, fine accuracy: 0.9061
#
# Iteration 47/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2870 e);
# Train Loss: 0.4215, Validation Loss: 0.3398, Validation Accuracy: 0.9444
# Test - coarse accuracy: 0.9412, fine accuracy: 0.9072
#
# Iteration 48/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2835 e);
# Train Loss: 0.4137, Validation Loss: 0.4276, Validation Accuracy: 0.9151
# Test - coarse accuracy: 0.9188, fine accuracy: 0.8836
#
# Iteration 49/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2810 e);
# Train Loss: 0.4017, Validation Loss: 0.3427, Validation Accuracy: 0.9481
# Test - coarse accuracy: 0.9559, fine accuracy: 0.9187
#
# Iteration 50/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2845 e);
# Train Loss: 0.3575, Validation Loss: 0.3320, Validation Accuracy: 0.9593
# Test - coarse accuracy: 0.9375, fine accuracy: 0.9036
#
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2895 e);
# Train Loss: 2.3381, Validation Loss: 2.1934, Validation Accuracy: 0.5444
# Test - coarse accuracy: 0.5294, fine accuracy: 0.5422
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2891 e);
# Train Loss: 2.2545, Validation Loss: 2.1591, Validation Accuracy: 0.6111
# Test - coarse accuracy: 0.6103, fine accuracy: 0.6047
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2825 e);
# Train Loss: 2.0422, Validation Loss: 1.9598, Validation Accuracy: 0.7196
# Test - coarse accuracy: 0.6974, fine accuracy: 0.6981
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2814 e);
# Train Loss: 1.9227, Validation Loss: 1.8434, Validation Accuracy: 0.6089
# Test - coarse accuracy: 0.6384, fine accuracy: 0.6782
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2830 e);
# Train Loss: 1.7914, Validation Loss: 1.6679, Validation Accuracy: 0.6926
# Test - coarse accuracy: 0.7059, fine accuracy: 0.7378
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2852 e);
# Train Loss: 1.6370, Validation Loss: 1.4619, Validation Accuracy: 0.7491
# Test - coarse accuracy: 0.6900, fine accuracy: 0.7269
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 1.4747, Validation Loss: 1.3449, Validation Accuracy: 0.7481
# Test - coarse accuracy: 0.7500, fine accuracy: 0.7338
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2843 e);
# Train Loss: 1.3393, Validation Loss: 1.2117, Validation Accuracy: 0.7741
# Test - coarse accuracy: 0.7463, fine accuracy: 0.7026
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2897 e);
# Train Loss: 1.2384, Validation Loss: 1.0618, Validation Accuracy: 0.8148
# Test - coarse accuracy: 0.8162, fine accuracy: 0.7409
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2856 e);
# Train Loss: 1.0937, Validation Loss: 1.0754, Validation Accuracy: 0.7601
# Test - coarse accuracy: 0.7934, fine accuracy: 0.7881
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2930 e);
# Train Loss: 1.0358, Validation Loss: 1.0092, Validation Accuracy: 0.8000
# Test - coarse accuracy: 0.8235, fine accuracy: 0.8208
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2926 e);
# Train Loss: 0.9952, Validation Loss: 0.8744, Validation Accuracy: 0.8556
# Test - coarse accuracy: 0.8419, fine accuracy: 0.8507
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2836 e);
# Train Loss: 0.9420, Validation Loss: 0.8408, Validation Accuracy: 0.8815
# Test - coarse accuracy: 0.8713, fine accuracy: 0.8343
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2797 e);
# Train Loss: 0.8555, Validation Loss: 0.8477, Validation Accuracy: 0.8630
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8609
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2932 e);
# Train Loss: 0.8244, Validation Loss: 0.7655, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.8897, fine accuracy: 0.8375
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2797 e);
# Train Loss: 0.7650, Validation Loss: 0.7873, Validation Accuracy: 0.8889
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8543
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2798 e);
# Train Loss: 0.7409, Validation Loss: 0.6759, Validation Accuracy: 0.8926
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8827
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2804 e);
# Train Loss: 0.6775, Validation Loss: 0.6469, Validation Accuracy: 0.9004
# Test - coarse accuracy: 0.8672, fine accuracy: 0.8391
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2802 e);
# Train Loss: 0.6768, Validation Loss: 0.6876, Validation Accuracy: 0.8598
# Test - coarse accuracy: 0.9077, fine accuracy: 0.8513
#
# Iteration 20/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2800 e);
# Train Loss: 0.6519, Validation Loss: 0.6405, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8910
#
# Iteration 21/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2800 e);
# Train Loss: 0.6067, Validation Loss: 0.6472, Validation Accuracy: 0.8930
# Test - coarse accuracy: 0.8893, fine accuracy: 0.8692
#
# Iteration 22/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2797 e);
# Train Loss: 0.6064, Validation Loss: 0.5887, Validation Accuracy: 0.8967
# Test - coarse accuracy: 0.8856, fine accuracy: 0.8705
#
# Iteration 23/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2795 e);
# Train Loss: 0.5801, Validation Loss: 0.5618, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9154
#
# Iteration 24/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2850 e);
# Train Loss: 0.5383, Validation Loss: 0.5479, Validation Accuracy: 0.9222
# Test - coarse accuracy: 0.8860, fine accuracy: 0.8399
#
# Iteration 25/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2835 e);
# Train Loss: 0.5598, Validation Loss: 0.4862, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8876
#
# Iteration 26/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.5373, Validation Loss: 0.5320, Validation Accuracy: 0.9259
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8778
#
# Iteration 27/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2844 e);
# Train Loss: 0.5071, Validation Loss: 0.5123, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9081, fine accuracy: 0.9045
#
# Iteration 28/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2878 e);
# Train Loss: 0.5126, Validation Loss: 0.5618, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.9118, fine accuracy: 0.9144
#
# Iteration 29/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2867 e);
# Train Loss: 0.5011, Validation Loss: 0.5253, Validation Accuracy: 0.8819
# Test - coarse accuracy: 0.9114, fine accuracy: 0.8983
#
# Iteration 30/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2860 e);
# Train Loss: 0.5712, Validation Loss: 0.5162, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.9596, fine accuracy: 0.9430
#
# Iteration 31/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2870 e);
# Train Loss: 0.4699, Validation Loss: 0.5078, Validation Accuracy: 0.9225
# Test - coarse accuracy: 0.9041, fine accuracy: 0.9030
#
# Iteration 32/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2860 e);
# Train Loss: 0.4719, Validation Loss: 0.4448, Validation Accuracy: 0.9225
# Test - coarse accuracy: 0.9225, fine accuracy: 0.9045
#
# Iteration 33/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2846 e);
# Train Loss: 0.4647, Validation Loss: 0.4740, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8846
#
# Iteration 34/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2817 e);
# Train Loss: 0.4949, Validation Loss: 0.4308, Validation Accuracy: 0.9188
# Test - coarse accuracy: 0.9410, fine accuracy: 0.9112
#
# Iteration 35/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2861 e);
# Train Loss: 0.4559, Validation Loss: 0.4741, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8816
#
# Iteration 36/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2864 e);
# Train Loss: 0.4502, Validation Loss: 0.4009, Validation Accuracy: 0.9373
# Test - coarse accuracy: 0.9262, fine accuracy: 0.8610
#
# Iteration 37/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2835 e);
# Train Loss: 0.4412, Validation Loss: 0.4395, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.9154, fine accuracy: 0.9052
#
# Iteration 38/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2868 e);
# Train Loss: 0.4277, Validation Loss: 0.4567, Validation Accuracy: 0.9222
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9073
#
# Iteration 39/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2839 e);
# Train Loss: 0.4541, Validation Loss: 0.4306, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9191, fine accuracy: 0.9000
#
# Iteration 40/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2851 e);
# Train Loss: 0.4125, Validation Loss: 0.4189, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9191, fine accuracy: 0.8982
#
# Iteration 41/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2843 e);
# Train Loss: 0.4038, Validation Loss: 0.4438, Validation Accuracy: 0.9222
# Test - coarse accuracy: 0.9449, fine accuracy: 0.9329
#
# Iteration 42/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2848 e);
# Train Loss: 0.4210, Validation Loss: 0.3811, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9338, fine accuracy: 0.8939
#
# Iteration 43/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2849 e);
# Train Loss: 0.4309, Validation Loss: 0.3789, Validation Accuracy: 0.9519
# Test - coarse accuracy: 0.9338, fine accuracy: 0.9284
#
# Iteration 44/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2847 e);
# Train Loss: 0.4006, Validation Loss: 0.4219, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9412, fine accuracy: 0.9398
#
# Iteration 45/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.3823, Validation Loss: 0.4345, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9228
#
# Iteration 46/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2858 e);
# Train Loss: 0.4113, Validation Loss: 0.3781, Validation Accuracy: 0.9373
# Test - coarse accuracy: 0.9483, fine accuracy: 0.9190
#
# Iteration 47/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2855 e);
# Train Loss: 0.3874, Validation Loss: 0.3769, Validation Accuracy: 0.9519
# Test - coarse accuracy: 0.9375, fine accuracy: 0.9188
#
# Iteration 48/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2834 e);
# Train Loss: 0.4112, Validation Loss: 0.3566, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9522, fine accuracy: 0.9086
#
# Iteration 49/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2875 e);
# Train Loss: 0.4040, Validation Loss: 0.3903, Validation Accuracy: 0.9373
# Test - coarse accuracy: 0.9336, fine accuracy: 0.9081
#
# Iteration 50/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2849 e);
# Train Loss: 0.3998, Validation Loss: 0.3752, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9375, fine accuracy: 0.9013
#
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1484 n, 2921 e);
# Train Loss: 2.3522, Validation Loss: 2.1969, Validation Accuracy: 0.2872
# Test - coarse accuracy: 0.3591, fine accuracy: 0.3586
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2843 e);
# Train Loss: 2.2338, Validation Loss: 2.1611, Validation Accuracy: 0.7749
# Test - coarse accuracy: 0.7269, fine accuracy: 0.7410
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2784 e);
# Train Loss: 2.0494, Validation Loss: 1.9754, Validation Accuracy: 0.7712
# Test - coarse accuracy: 0.7712, fine accuracy: 0.7670
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2755 e);
# Train Loss: 1.9156, Validation Loss: 1.8431, Validation Accuracy: 0.7111
# Test - coarse accuracy: 0.7426, fine accuracy: 0.7769
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2809 e);
# Train Loss: 1.8002, Validation Loss: 1.6663, Validation Accuracy: 0.7259
# Test - coarse accuracy: 0.7647, fine accuracy: 0.7853
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2811 e);
# Train Loss: 1.6532, Validation Loss: 1.5030, Validation Accuracy: 0.7232
# Test - coarse accuracy: 0.7196, fine accuracy: 0.7458
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2837 e);
# Train Loss: 1.5195, Validation Loss: 1.4022, Validation Accuracy: 0.7528
# Test - coarse accuracy: 0.7860, fine accuracy: 0.7801
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2833 e);
# Train Loss: 1.4065, Validation Loss: 1.2149, Validation Accuracy: 0.7852
# Test - coarse accuracy: 0.7831, fine accuracy: 0.8375
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2835 e);
# Train Loss: 1.2538, Validation Loss: 1.0897, Validation Accuracy: 0.8413
# Test - coarse accuracy: 0.7897, fine accuracy: 0.8218
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2831 e);
# Train Loss: 1.1127, Validation Loss: 1.0565, Validation Accuracy: 0.8081
# Test - coarse accuracy: 0.7934, fine accuracy: 0.8448
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2832 e);
# Train Loss: 1.0353, Validation Loss: 0.9432, Validation Accuracy: 0.8704
# Test - coarse accuracy: 0.8566, fine accuracy: 0.8707
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2862 e);
# Train Loss: 0.9340, Validation Loss: 0.8499, Validation Accuracy: 0.8893
# Test - coarse accuracy: 0.8487, fine accuracy: 0.8486
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2853 e);
# Train Loss: 0.9236, Validation Loss: 0.8032, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8923
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2853 e);
# Train Loss: 0.8299, Validation Loss: 0.8043, Validation Accuracy: 0.8741
# Test - coarse accuracy: 0.9081, fine accuracy: 0.8882
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2851 e);
# Train Loss: 0.7653, Validation Loss: 0.8140, Validation Accuracy: 0.8782
# Test - coarse accuracy: 0.8856, fine accuracy: 0.8722
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2861 e);
# Train Loss: 0.7220, Validation Loss: 0.7739, Validation Accuracy: 0.8778
# Test - coarse accuracy: 0.8713, fine accuracy: 0.8876
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2853 e);
# Train Loss: 0.7105, Validation Loss: 0.6885, Validation Accuracy: 0.8630
# Test - coarse accuracy: 0.9044, fine accuracy: 0.8582
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.7133, Validation Loss: 0.6476, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.8897, fine accuracy: 0.8885
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.6605, Validation Loss: 0.6893, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.9118, fine accuracy: 0.8913
#
# Iteration 20/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2847 e);
# Train Loss: 0.6455, Validation Loss: 0.5923, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9081, fine accuracy: 0.8786
#
# Iteration 21/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2853 e);
# Train Loss: 0.5842, Validation Loss: 0.6458, Validation Accuracy: 0.8778
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8689
#
# Iteration 22/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2839 e);
# Train Loss: 0.5822, Validation Loss: 0.6282, Validation Accuracy: 0.8889
# Test - coarse accuracy: 0.9191, fine accuracy: 0.8830
#
# Iteration 23/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2856 e);
# Train Loss: 0.5762, Validation Loss: 0.5659, Validation Accuracy: 0.8893
# Test - coarse accuracy: 0.9151, fine accuracy: 0.8767
#
# Iteration 24/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2854 e);
# Train Loss: 0.6067, Validation Loss: 0.5176, Validation Accuracy: 0.9259
# Test - coarse accuracy: 0.9338, fine accuracy: 0.8959
#
# Iteration 25/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.5463, Validation Loss: 0.5789, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.9191, fine accuracy: 0.8876
#
# Iteration 26/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2844 e);
# Train Loss: 0.5654, Validation Loss: 0.5688, Validation Accuracy: 0.8889
# Test - coarse accuracy: 0.9265, fine accuracy: 0.9056
#
# Iteration 27/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2804 e);
# Train Loss: 0.5142, Validation Loss: 0.5898, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8720
#
# Iteration 28/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.5189, Validation Loss: 0.4780, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.8971, fine accuracy: 0.8918
#
# Iteration 29/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2862 e);
# Train Loss: 0.5233, Validation Loss: 0.5645, Validation Accuracy: 0.8926
# Test - coarse accuracy: 0.9228, fine accuracy: 0.9035
#
# Iteration 30/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2878 e);
# Train Loss: 0.4896, Validation Loss: 0.4504, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9044, fine accuracy: 0.9056
#
# Iteration 31/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2854 e);
# Train Loss: 0.5149, Validation Loss: 0.4220, Validation Accuracy: 0.9262
# Test - coarse accuracy: 0.8893, fine accuracy: 0.8866
#
# Iteration 32/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2851 e);
# Train Loss: 0.4699, Validation Loss: 0.5093, Validation Accuracy: 0.8963
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8760
#
# Iteration 33/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2848 e);
# Train Loss: 0.4841, Validation Loss: 0.4734, Validation Accuracy: 0.9148
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8696
#
# Iteration 34/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2901 e);
# Train Loss: 0.4649, Validation Loss: 0.4532, Validation Accuracy: 0.9114
# Test - coarse accuracy: 0.9077, fine accuracy: 0.8855
#
# Iteration 35/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2854 e);
# Train Loss: 0.4206, Validation Loss: 0.4826, Validation Accuracy: 0.9077
# Test - coarse accuracy: 0.9041, fine accuracy: 0.9025
#
# Iteration 36/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2763 e);
# Train Loss: 0.5089, Validation Loss: 0.4320, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9154, fine accuracy: 0.8813
#
# Iteration 37/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2859 e);
# Train Loss: 0.4394, Validation Loss: 0.4279, Validation Accuracy: 0.9148
# Test - coarse accuracy: 0.9412, fine accuracy: 0.9120
#
# Iteration 38/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2891 e);
# Train Loss: 0.4248, Validation Loss: 0.4544, Validation Accuracy: 0.9222
# Test - coarse accuracy: 0.8934, fine accuracy: 0.8539
#
# Iteration 39/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2825 e);
# Train Loss: 0.4524, Validation Loss: 0.4413, Validation Accuracy: 0.9222
# Test - coarse accuracy: 0.9228, fine accuracy: 0.9085
#
# Iteration 40/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2875 e);
# Train Loss: 0.4406, Validation Loss: 0.4108, Validation Accuracy: 0.9262
# Test - coarse accuracy: 0.9188, fine accuracy: 0.9201
#
# Iteration 41/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2774 e);
# Train Loss: 0.4515, Validation Loss: 0.4762, Validation Accuracy: 0.9114
# Test - coarse accuracy: 0.9446, fine accuracy: 0.9181
#
# Iteration 42/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2886 e);
# Train Loss: 0.4514, Validation Loss: 0.3603, Validation Accuracy: 0.9557
# Test - coarse accuracy: 0.9151, fine accuracy: 0.8934
#
# Iteration 43/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2856 e);
# Train Loss: 0.4089, Validation Loss: 0.4530, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.9265, fine accuracy: 0.8985
#
# Iteration 44/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2864 e);
# Train Loss: 0.4185, Validation Loss: 0.4029, Validation Accuracy: 0.9520
# Test - coarse accuracy: 0.9188, fine accuracy: 0.9150
#
# Iteration 45/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2833 e);
# Train Loss: 0.4708, Validation Loss: 0.3601, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9191, fine accuracy: 0.9102
#
# Iteration 46/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2889 e);
# Train Loss: 0.3979, Validation Loss: 0.3547, Validation Accuracy: 0.9370
# Test - coarse accuracy: 0.9007, fine accuracy: 0.8887
#
# Iteration 47/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2840 e);
# Train Loss: 0.3920, Validation Loss: 0.3950, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9522, fine accuracy: 0.9274
#
# Iteration 48/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2879 e);
# Train Loss: 0.3617, Validation Loss: 0.3633, Validation Accuracy: 0.9299
# Test - coarse accuracy: 0.9077, fine accuracy: 0.8668
#
# Iteration 49/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2836 e);
# Train Loss: 0.3848, Validation Loss: 0.3974, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9412, fine accuracy: 0.9130
#
# Iteration 50/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2843 e);
# Train Loss: 0.3828, Validation Loss: 0.3729, Validation Accuracy: 0.9370
# Test - coarse accuracy: 0.9485, fine accuracy: 0.8902
#
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (2208 n, 4427 e);
# Train Loss: 2.3487, Validation Loss: 2.2117, Validation Accuracy: 0.3900
# Test - coarse accuracy: 0.4086, fine accuracy: 0.4254
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1878 n, 3680 e);
# Train Loss: 2.2478, Validation Loss: 2.1778, Validation Accuracy: 0.6187
# Test - coarse accuracy: 0.5544, fine accuracy: 0.5951
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1963 n, 3895 e);
# Train Loss: 2.0253, Validation Loss: 1.9249, Validation Accuracy: 0.7245
# Test - coarse accuracy: 0.7183, fine accuracy: 0.7588
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1803 n, 3512 e);
# Train Loss: 1.9236, Validation Loss: 1.7810, Validation Accuracy: 0.7972
# Test - coarse accuracy: 0.7597, fine accuracy: 0.8089
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1557 n, 2978 e);
# Train Loss: 1.8145, Validation Loss: 1.6786, Validation Accuracy: 0.7235
# Test - coarse accuracy: 0.7596, fine accuracy: 0.8200
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1357 n, 2491 e);
# Train Loss: 1.7260, Validation Loss: 1.5822, Validation Accuracy: 0.7196
# Test - coarse accuracy: 0.7831, fine accuracy: 0.7892
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2699 e);
# Train Loss: 1.5175, Validation Loss: 1.4021, Validation Accuracy: 0.7380
# Test - coarse accuracy: 0.7528, fine accuracy: 0.7747
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2771 e);
# Train Loss: 1.3820, Validation Loss: 1.1856, Validation Accuracy: 0.8044
# Test - coarse accuracy: 0.7749, fine accuracy: 0.8145
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2801 e);
# Train Loss: 1.2300, Validation Loss: 1.0822, Validation Accuracy: 0.8407
# Test - coarse accuracy: 0.8199, fine accuracy: 0.8647
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2778 e);
# Train Loss: 1.1071, Validation Loss: 0.9762, Validation Accuracy: 0.8519
# Test - coarse accuracy: 0.8125, fine accuracy: 0.8073
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2790 e);
# Train Loss: 1.0104, Validation Loss: 0.8939, Validation Accuracy: 0.8593
# Test - coarse accuracy: 0.8346, fine accuracy: 0.8311
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2797 e);
# Train Loss: 0.9332, Validation Loss: 0.8411, Validation Accuracy: 0.8556
# Test - coarse accuracy: 0.8676, fine accuracy: 0.8852
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2767 e);
# Train Loss: 0.8796, Validation Loss: 0.7972, Validation Accuracy: 0.9114
# Test - coarse accuracy: 0.8819, fine accuracy: 0.8675
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2812 e);
# Train Loss: 0.8049, Validation Loss: 0.7258, Validation Accuracy: 0.8963
# Test - coarse accuracy: 0.8713, fine accuracy: 0.8733
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2825 e);
# Train Loss: 0.7402, Validation Loss: 0.7961, Validation Accuracy: 0.8856
# Test - coarse accuracy: 0.8893, fine accuracy: 0.9056
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2759 e);
# Train Loss: 0.7146, Validation Loss: 0.7108, Validation Accuracy: 0.8708
# Test - coarse accuracy: 0.8782, fine accuracy: 0.8887
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2759 e);
# Train Loss: 0.6775, Validation Loss: 0.6832, Validation Accuracy: 0.8967
# Test - coarse accuracy: 0.8524, fine accuracy: 0.8748
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2756 e);
# Train Loss: 0.6513, Validation Loss: 0.6734, Validation Accuracy: 0.8630
# Test - coarse accuracy: 0.8824, fine accuracy: 0.9029
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2763 e);
# Train Loss: 0.6700, Validation Loss: 0.5790, Validation Accuracy: 0.8856
# Test - coarse accuracy: 0.9077, fine accuracy: 0.8952
#
# Iteration 20/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2832 e);
# Train Loss: 0.5953, Validation Loss: 0.6512, Validation Accuracy: 0.8782
# Test - coarse accuracy: 0.9004, fine accuracy: 0.8745
#
# Iteration 21/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2825 e);
# Train Loss: 0.5942, Validation Loss: 0.5892, Validation Accuracy: 0.8778
# Test - coarse accuracy: 0.9118, fine accuracy: 0.9157
#
# Iteration 22/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2822 e);
# Train Loss: 0.5987, Validation Loss: 0.6057, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.8971, fine accuracy: 0.9004
#
# Iteration 23/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2801 e);
# Train Loss: 0.5817, Validation Loss: 0.5859, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.8824, fine accuracy: 0.8810
#
# Iteration 24/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2826 e);
# Train Loss: 0.5642, Validation Loss: 0.5655, Validation Accuracy: 0.8930
# Test - coarse accuracy: 0.9188, fine accuracy: 0.8978
#
# Iteration 25/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2813 e);
# Train Loss: 0.5433, Validation Loss: 0.4884, Validation Accuracy: 0.9225
# Test - coarse accuracy: 0.8745, fine accuracy: 0.8867
#
# Iteration 26/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2807 e);
# Train Loss: 0.5650, Validation Loss: 0.5287, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9118, fine accuracy: 0.9242
#
# Iteration 27/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2808 e);
# Train Loss: 0.5275, Validation Loss: 0.5131, Validation Accuracy: 0.9188
# Test - coarse accuracy: 0.8782, fine accuracy: 0.9026
#
# Iteration 28/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2792 e);
# Train Loss: 0.5149, Validation Loss: 0.5227, Validation Accuracy: 0.9074
# Test - coarse accuracy: 0.8897, fine accuracy: 0.8960
#
# Iteration 29/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2795 e);
# Train Loss: 0.5164, Validation Loss: 0.5421, Validation Accuracy: 0.8852
# Test - coarse accuracy: 0.9007, fine accuracy: 0.9170
#
# Iteration 30/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2803 e);
# Train Loss: 0.4850, Validation Loss: 0.4444, Validation Accuracy: 0.9148
# Test - coarse accuracy: 0.8750, fine accuracy: 0.8808
#
# Iteration 31/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2815 e);
# Train Loss: 0.5260, Validation Loss: 0.4711, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9081, fine accuracy: 0.9255
#
# Iteration 32/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2824 e);
# Train Loss: 0.4954, Validation Loss: 0.4554, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.9044, fine accuracy: 0.9101
#
# Iteration 33/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2816 e);
# Train Loss: 0.4722, Validation Loss: 0.4995, Validation Accuracy: 0.8963
# Test - coarse accuracy: 0.9228, fine accuracy: 0.9191
#
# Iteration 34/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2790 e);
# Train Loss: 0.4654, Validation Loss: 0.4642, Validation Accuracy: 0.9114
# Test - coarse accuracy: 0.9114, fine accuracy: 0.9037
#
# Iteration 35/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2796 e);
# Train Loss: 0.4465, Validation Loss: 0.4535, Validation Accuracy: 0.9037
# Test - coarse accuracy: 0.9118, fine accuracy: 0.9178
#
# Iteration 36/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2793 e);
# Train Loss: 0.4600, Validation Loss: 0.4501, Validation Accuracy: 0.8930
# Test - coarse accuracy: 0.9151, fine accuracy: 0.9204
#
# Iteration 37/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2792 e);
# Train Loss: 0.4742, Validation Loss: 0.4170, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.9154, fine accuracy: 0.9132
#
# Iteration 38/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2788 e);
# Train Loss: 0.4328, Validation Loss: 0.4071, Validation Accuracy: 0.9333
# Test - coarse accuracy: 0.8787, fine accuracy: 0.8902
#
# Iteration 39/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2799 e);
# Train Loss: 0.4373, Validation Loss: 0.4687, Validation Accuracy: 0.9041
# Test - coarse accuracy: 0.9188, fine accuracy: 0.9037
#
# Iteration 40/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2790 e);
# Train Loss: 0.4253, Validation Loss: 0.4568, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9301, fine accuracy: 0.9343
#
# Iteration 41/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2769 e);
# Train Loss: 0.3937, Validation Loss: 0.4328, Validation Accuracy: 0.9151
# Test - coarse accuracy: 0.8930, fine accuracy: 0.9030
#
# Iteration 42/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2792 e);
# Train Loss: 0.4330, Validation Loss: 0.4136, Validation Accuracy: 0.9296
# Test - coarse accuracy: 0.9191, fine accuracy: 0.9140
#
# Iteration 43/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2797 e);
# Train Loss: 0.4222, Validation Loss: 0.4065, Validation Accuracy: 0.9444
# Test - coarse accuracy: 0.9191, fine accuracy: 0.9161
#
# Iteration 44/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2789 e);
# Train Loss: 0.4370, Validation Loss: 0.3967, Validation Accuracy: 0.9556
# Test - coarse accuracy: 0.9412, fine accuracy: 0.9263
#
# Iteration 45/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2852 e);
# Train Loss: 0.4077, Validation Loss: 0.4344, Validation Accuracy: 0.9225
# Test - coarse accuracy: 0.9151, fine accuracy: 0.9137
#
# Iteration 46/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2796 e);
# Train Loss: 0.4066, Validation Loss: 0.4118, Validation Accuracy: 0.9185
# Test - coarse accuracy: 0.9522, fine accuracy: 0.9398
#
# Iteration 47/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2781 e);
# Train Loss: 0.4123, Validation Loss: 0.3984, Validation Accuracy: 0.9262
# Test - coarse accuracy: 0.9594, fine accuracy: 0.9170
#
# Iteration 48/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1354 n, 2790 e);
# Train Loss: 0.3810, Validation Loss: 0.4256, Validation Accuracy: 0.9111
# Test - coarse accuracy: 0.9449, fine accuracy: 0.9279
#
# Iteration 49/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2794 e);
# Train Loss: 0.3964, Validation Loss: 0.3595, Validation Accuracy: 0.9336
# Test - coarse accuracy: 0.9299, fine accuracy: 0.9211
#
# Iteration 50/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1355 n, 2793 e);
# Train Loss: 0.3812, Validation Loss: 0.3640, Validation Accuracy: 0.9373
# Test - coarse accuracy: 0.9373, fine accuracy: 0.9431
#
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (555 n, 701 e);
# Train Loss: 2.4027, Validation Loss: 2.2888, Validation Accuracy: 0.3333
# Test - coarse accuracy: 0.3333, fine accuracy: 0.2895
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (542 n, 954 e);
# Train Loss: 2.3089, Validation Loss: 2.1921, Validation Accuracy: 0.6019
# Test - coarse accuracy: 0.5321, fine accuracy: 0.4964
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (563 n, 746 e);
# Train Loss: 2.1487, Validation Loss: 2.0920, Validation Accuracy: 0.5804
# Test - coarse accuracy: 0.5526, fine accuracy: 0.6181
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 780 e);
# Train Loss: 2.0853, Validation Loss: 2.0503, Validation Accuracy: 0.5370
# Test - coarse accuracy: 0.5364, fine accuracy: 0.2348
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (556 n, 778 e);
# Train Loss: 1.9973, Validation Loss: 1.8900, Validation Accuracy: 0.5495
# Test - coarse accuracy: 0.5179, fine accuracy: 0.5991
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 837 e);
# Train Loss: 1.8493, Validation Loss: 1.8650, Validation Accuracy: 0.5185
# Test - coarse accuracy: 0.6000, fine accuracy: 0.5371
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (542 n, 770 e);
# Train Loss: 1.8336, Validation Loss: 1.7098, Validation Accuracy: 0.5185
# Test - coarse accuracy: 0.5138, fine accuracy: 0.5275
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (556 n, 728 e);
# Train Loss: 1.6957, Validation Loss: 1.5788, Validation Accuracy: 0.6306
# Test - coarse accuracy: 0.6339, fine accuracy: 0.3262
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 711 e);
# Train Loss: 1.6117, Validation Loss: 1.6656, Validation Accuracy: 0.5556
# Test - coarse accuracy: 0.6818, fine accuracy: 0.5956
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (575 n, 872 e);
# Train Loss: 1.5959, Validation Loss: 1.5021, Validation Accuracy: 0.6870
# Test - coarse accuracy: 0.7130, fine accuracy: 0.7285
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (546 n, 784 e);
# Train Loss: 1.4126, Validation Loss: 1.3595, Validation Accuracy: 0.7615
# Test - coarse accuracy: 0.8091, fine accuracy: 0.8014
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (550 n, 838 e);
# Train Loss: 1.4766, Validation Loss: 1.4419, Validation Accuracy: 0.7091
# Test - coarse accuracy: 0.7727, fine accuracy: 0.7549
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 813 e);
# Train Loss: 1.3096, Validation Loss: 1.2602, Validation Accuracy: 0.7778
# Test - coarse accuracy: 0.7818, fine accuracy: 0.8469
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 857 e);
# Train Loss: 1.2374, Validation Loss: 1.2303, Validation Accuracy: 0.8241
# Test - coarse accuracy: 0.7818, fine accuracy: 0.7990
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (545 n, 731 e);
# Train Loss: 1.2619, Validation Loss: 1.1701, Validation Accuracy: 0.7706
# Test - coarse accuracy: 0.8073, fine accuracy: 0.7465
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 927 e);
# Train Loss: 1.3112, Validation Loss: 1.0698, Validation Accuracy: 0.8426
# Test - coarse accuracy: 0.8091, fine accuracy: 0.8048
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (575 n, 770 e);
# Train Loss: 1.1449, Validation Loss: 1.1557, Validation Accuracy: 0.8609
# Test - coarse accuracy: 0.8870, fine accuracy: 0.8734
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 881 e);
# Train Loss: 1.1058, Validation Loss: 1.0637, Validation Accuracy: 0.7963
# Test - coarse accuracy: 0.8909, fine accuracy: 0.2894
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (543 n, 944 e);
# Train Loss: 1.0490, Validation Loss: 0.9771, Validation Accuracy: 0.8426
# Test - coarse accuracy: 0.8455, fine accuracy: 0.8259
#
# Iteration 20/50
# ...
# Test - coarse accuracy: 0.7722, fine accuracy: 0.7102
#
# Iteration 25/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (385 n, 629 e);
# Train Loss: 0.7343, Validation Loss: 0.8732, Validation Accuracy: 0.8052
# Test - coarse accuracy: 0.8442, fine accuracy: 0.8447
#
# Iteration 26/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (381 n, 639 e);
# Train Loss: 0.7690, Validation Loss: 0.4953, Validation Accuracy: 0.9342
# Test - coarse accuracy: 0.7922, fine accuracy: 0.8626
#
# Iteration 27/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (369 n, 640 e);
# Train Loss: 0.7383, Validation Loss: 0.6964, Validation Accuracy: 0.8219
# Test - coarse accuracy: 0.8267, fine accuracy: 0.8524
#
# Iteration 28/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (397 n, 662 e);
# Train Loss: 0.7036, Validation Loss: 0.8491, Validation Accuracy: 0.8481
# Test - coarse accuracy: 0.8750, fine accuracy: 0.8020
#
# Iteration 29/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (387 n, 653 e);
# Train Loss: 0.6333, Validation Loss: 0.8875, Validation Accuracy: 0.8052
# Test - coarse accuracy: 0.8333, fine accuracy: 0.7273
#
# Iteration 30/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (394 n, 651 e);
# Train Loss: 0.6933, Validation Loss: 0.5816, Validation Accuracy: 0.8462
# Test - coarse accuracy: 0.8375, fine accuracy: 0.9061
#
# Iteration 31/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (378 n, 629 e);
# Train Loss: 0.6222, Validation Loss: 0.8087, Validation Accuracy: 0.8267
# Test - coarse accuracy: 0.8701, fine accuracy: 0.7030
#
# Iteration 32/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (386 n, 631 e);
# Train Loss: 0.6137, Validation Loss: 0.9852, Validation Accuracy: 0.7662
# Test - coarse accuracy: 0.9487, fine accuracy: 0.9041
#
# Iteration 33/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (356 n, 569 e);
# Train Loss: 0.5533, Validation Loss: 0.9687, Validation Accuracy: 0.8310
# Test - coarse accuracy: 0.8056, fine accuracy: 0.8738
#
# Iteration 34/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (368 n, 615 e);
# Train Loss: 0.6491, Validation Loss: 0.5409, Validation Accuracy: 0.8767
# Test - coarse accuracy: 0.8667, fine accuracy: 0.8497
#
# Iteration 35/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (368 n, 619 e);
# Train Loss: 0.5799, Validation Loss: 0.6440, Validation Accuracy: 0.8493
# Test - coarse accuracy: 0.8267, fine accuracy: 0.8004
#
# Iteration 36/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (517 n, 785 e);
# Train Loss: 0.5750, Validation Loss: 0.7289, Validation Accuracy: 0.8252
# Test - coarse accuracy: 0.8462, fine accuracy: 0.7749
#
# Iteration 37/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (381 n, 647 e);
# Train Loss: 0.6339, Validation Loss: 0.6224, Validation Accuracy: 0.8421
# Test - coarse accuracy: 0.8571, fine accuracy: 0.6413
#
# Iteration 38/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (392 n, 652 e);
# Train Loss: 0.6099, Validation Loss: 0.5110, Validation Accuracy: 0.9103
# Test - coarse accuracy: 0.8734, fine accuracy: 0.8308
#
# Iteration 39/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (379 n, 647 e);
# Train Loss: 0.6436, Validation Loss: 0.5518, Validation Accuracy: 0.9067
# Test - coarse accuracy: 0.9221, fine accuracy: 0.8798
#
# Iteration 40/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (378 n, 633 e);
# Train Loss: 0.5391, Validation Loss: 0.8123, Validation Accuracy: 0.8133
# Test - coarse accuracy: 0.9481, fine accuracy: 0.8414
#
# Iteration 41/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (398 n, 624 e);
# Train Loss: 0.5604, Validation Loss: 0.7137, Validation Accuracy: 0.8987
# Test - coarse accuracy: 0.8765, fine accuracy: 0.8710
#
# Iteration 42/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (391 n, 684 e);
# Train Loss: 0.5538, Validation Loss: 0.6161, Validation Accuracy: 0.8718
# Test - coarse accuracy: 0.8481, fine accuracy: 0.8703
#
# Iteration 43/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (389 n, 680 e);
# Train Loss: 0.6594, Validation Loss: 0.4353, Validation Accuracy: 0.9351
# Test - coarse accuracy: 0.9114, fine accuracy: 0.9199
#
# Iteration 44/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (398 n, 656 e);
# Train Loss: 0.5515, Validation Loss: 0.6814, Validation Accuracy: 0.8987
# Test - coarse accuracy: 0.8025, fine accuracy: 0.7321
#
# Iteration 45/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (394 n, 665 e);
# Train Loss: 0.5854, Validation Loss: 0.5805, Validation Accuracy: 0.8590
# Test - coarse accuracy: 0.9125, fine accuracy: 0.8191
#
# Iteration 46/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (402 n, 665 e);
# Train Loss: 0.6678, Validation Loss: 0.4788, Validation Accuracy: 0.8875
# Test - coarse accuracy: 0.9012, fine accuracy: 0.8908
#
# Iteration 47/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (385 n, 648 e);
# Train Loss: 0.5269, Validation Loss: 0.5760, Validation Accuracy: 0.8571
# Test - coarse accuracy: 0.8701, fine accuracy: 0.7052
#
# Iteration 48/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (379 n, 648 e);
# Train Loss: 0.5479, Validation Loss: 0.4912, Validation Accuracy: 0.8800
# Test - coarse accuracy: 0.8571, fine accuracy: 0.8247
#
# Iteration 49/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (381 n, 651 e);
# Train Loss: 0.5709, Validation Loss: 0.5507, Validation Accuracy: 0.8684
# Test - coarse accuracy: 0.8312, fine accuracy: 0.8859
#
# Iteration 50/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (373 n, 625 e);
# Train Loss: 0.6081, Validation Loss: 0.4434, Validation Accuracy: 0.9324
# Test - coarse accuracy: 0.8684, fine accuracy: 0.8649
#
# Iteration 01/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (1833 n, 3506 e);
# Train Loss: 2.3611, Validation Loss: 2.2017, Validation Accuracy: 0.4317
# Test - coarse accuracy: 0.4158, fine accuracy: 0.4108
#
# Iteration 02/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (1342 n, 2391 e);
# Train Loss: 2.2543, Validation Loss: 2.2025, Validation Accuracy: 0.6231
# Test - coarse accuracy: 0.5799, fine accuracy: 0.6297
#
# Iteration 03/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (1450 n, 2693 e);
# Train Loss: 2.0553, Validation Loss: 1.9760, Validation Accuracy: 0.6621
# Test - coarse accuracy: 0.6793, fine accuracy: 0.7252
#
# Iteration 04/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (1306 n, 2413 e);
# Train Loss: 1.9518, Validation Loss: 1.8360, Validation Accuracy: 0.6475
# Test - coarse accuracy: 0.7137, fine accuracy: 0.8322
#
# Iteration 05/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (1153 n, 2060 e);
# Train Loss: 1.8399, Validation Loss: 1.7096, Validation Accuracy: 0.6609
# Test - coarse accuracy: 0.6638, fine accuracy: 0.7365
#
# Iteration 06/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (966 n, 1728 e);
# Train Loss: 1.7395, Validation Loss: 1.6409, Validation Accuracy: 0.6321
# Test - coarse accuracy: 0.7010, fine accuracy: 0.7332
#
# Iteration 07/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (801 n, 1446 e);
# Train Loss: 1.6621, Validation Loss: 1.5094, Validation Accuracy: 0.6625
# Test - coarse accuracy: 0.7019, fine accuracy: 0.6806
#
# Iteration 08/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (708 n, 1253 e);
# Train Loss: 1.5442, Validation Loss: 1.3948, Validation Accuracy: 0.7447
# Test - coarse accuracy: 0.6713, fine accuracy: 0.7759
#
# Iteration 09/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (626 n, 1028 e);
# Train Loss: 1.4023, Validation Loss: 1.2193, Validation Accuracy: 0.7440
# Test - coarse accuracy: 0.6746, fine accuracy: 0.4964
#
# Iteration 10/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (560 n, 903 e);
# Train Loss: 1.3118, Validation Loss: 1.2591, Validation Accuracy: 0.7946
# Test - coarse accuracy: 0.7500, fine accuracy: 0.7864
#
# Iteration 11/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (531 n, 875 e);
# Train Loss: 1.2046, Validation Loss: 1.1937, Validation Accuracy: 0.7358
# Test - coarse accuracy: 0.7570, fine accuracy: 0.7164
#
# Iteration 12/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (504 n, 821 e);
# Train Loss: 1.0413, Validation Loss: 1.3772, Validation Accuracy: 0.7500
# Test - coarse accuracy: 0.7549, fine accuracy: 0.7690
#
# Iteration 13/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (614 n, 904 e);
# Train Loss: 1.0433, Validation Loss: 0.9897, Validation Accuracy: 0.7787
# Test - coarse accuracy: 0.7581, fine accuracy: 0.8084
#
# Iteration 14/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (463 n, 753 e);
# Train Loss: 1.1150, Validation Loss: 1.0294, Validation Accuracy: 0.8043
# Test - coarse accuracy: 0.7766, fine accuracy: 0.7411
#
# Iteration 15/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (449 n, 750 e);
# Train Loss: 0.9424, Validation Loss: 1.0946, Validation Accuracy: 0.7191
# Test - coarse accuracy: 0.7473, fine accuracy: 0.8680
#
# Iteration 16/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (477 n, 780 e);
# Train Loss: 0.9688, Validation Loss: 0.7945, Validation Accuracy: 0.8000
# Test - coarse accuracy: 0.7917, fine accuracy: 0.8422
#
# Iteration 17/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (573 n, 934 e);
# Train Loss: 0.9232, Validation Loss: 0.7833, Validation Accuracy: 0.8772
# Test - coarse accuracy: 0.8448, fine accuracy: 0.8753
#
# Iteration 18/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (489 n, 828 e);
# Train Loss: 0.9482, Validation Loss: 0.8529, Validation Accuracy: 0.8351
# Test - coarse accuracy: 0.8384, fine accuracy: 0.8278
#
# Iteration 19/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (497 n, 840 e);
# Train Loss: 0.8522, Validation Loss: 0.9261, Validation Accuracy: 0.7879
# Test - coarse accuracy: 0.8300, fine accuracy: 0.8818
#
# Iteration 20/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (504 n, 865 e);
# Train Loss: 0.8180, Validation Loss: 1.0418, Validation Accuracy: 0.7500
# Test - coarse accuracy: 0.7941, fine accuracy: 0.8144
#
# Iteration 21/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (529 n, 874 e);
# Train Loss: 0.8709, Validation Loss: 0.7483, Validation Accuracy: 0.8381
# Test - coarse accuracy: 0.8224, fine accuracy: 0.8502
#
# Iteration 22/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (504 n, 874 e);
# Train Loss: 0.8368, Validation Loss: 0.9114, Validation Accuracy: 0.7600
# Test - coarse accuracy: 0.8431, fine accuracy: 0.8850
#
# Iteration 23/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (514 n, 873 e);
# Train Loss: 0.8449, Validation Loss: 1.0860, Validation Accuracy: 0.7941
# Test - coarse accuracy: 0.8365, fine accuracy: 0.8168
#
# Iteration 24/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (513 n, 938 e);
# Train Loss: 0.8340, Validation Loss: 0.7017, Validation Accuracy: 0.8627
# Test - coarse accuracy: 0.8077, fine accuracy: 0.8831
#
# Iteration 25/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (529 n, 947 e);
# Train Loss: 0.7944, Validation Loss: 0.8777, Validation Accuracy: 0.7333
# Test - coarse accuracy: 0.8598, fine accuracy: 0.8793
#
# Iteration 26/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (531 n, 948 e);
# Train Loss: 0.6972, Validation Loss: 0.6224, Validation Accuracy: 0.8868
# Test - coarse accuracy: 0.7664, fine accuracy: 0.8557
#
# Iteration 27/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (534 n, 927 e);
# Train Loss: 0.6929, Validation Loss: 0.6906, Validation Accuracy: 0.8302
# Test - coarse accuracy: 0.7963, fine accuracy: 0.9048
#
# Iteration 28/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (552 n, 971 e);
# Train Loss: 0.6997, Validation Loss: 0.6693, Validation Accuracy: 0.8091
# Test - coarse accuracy: 0.8559, fine accuracy: 0.8734
#
# Iteration 29/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (557 n, 971 e);
# Train Loss: 0.6901, Validation Loss: 0.6957, Validation Accuracy: 0.8468
# Test - coarse accuracy: 0.8214, fine accuracy: 0.8441
#
# Iteration 30/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (546 n, 999 e);
# Train Loss: 0.7513, Validation Loss: 0.7151, Validation Accuracy: 0.7982
# Test - coarse accuracy: 0.9000, fine accuracy: 0.9000
#
# Iteration 31/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (541 n, 1005 e);
# Train Loss: 0.6958, Validation Loss: 0.5707, Validation Accuracy: 0.8796
# Test - coarse accuracy: 0.8349, fine accuracy: 0.8563
#
# Iteration 32/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (541 n, 959 e);
# Train Loss: 0.6639, Validation Loss: 0.6998, Validation Accuracy: 0.8426
# Test - coarse accuracy: 0.8257, fine accuracy: 0.8400
#
# Iteration 33/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (536 n, 996 e);
# Train Loss: 0.7056, Validation Loss: 0.7062, Validation Accuracy: 0.8224
# Test - coarse accuracy: 0.7963, fine accuracy: 0.7436
#
# Iteration 34/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (637 n, 1075 e);
# Train Loss: 0.6338, Validation Loss: 0.5230, Validation Accuracy: 0.8898
# Test - coarse accuracy: 0.8516, fine accuracy: 0.8707
#
# Iteration 35/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (541 n, 952 e);
# Train Loss: 0.6127, Validation Loss: 0.7650, Validation Accuracy: 0.8241
# Test - coarse accuracy: 0.8624, fine accuracy: 0.9353
#
# Iteration 36/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (554 n, 979 e);
# Train Loss: 0.6424, Validation Loss: 0.5454, Validation Accuracy: 0.9273
# Test - coarse accuracy: 0.8214, fine accuracy: 0.9215
#
# Iteration 37/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (558 n, 1053 e);
# Train Loss: 0.6206, Validation Loss: 0.6101, Validation Accuracy: 0.8198
# Test - coarse accuracy: 0.7965, fine accuracy: 0.7391
#
# Iteration 38/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (565 n, 1006 e);
# Train Loss: 0.5998, Validation Loss: 0.6038, Validation Accuracy: 0.8142
# Test - coarse accuracy: 0.8673, fine accuracy: 0.8764
#
# Iteration 39/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (560 n, 1047 e);
# Train Loss: 0.5757, Validation Loss: 0.7376, Validation Accuracy: 0.7946
# Test - coarse accuracy: 0.8750, fine accuracy: 0.8826
#
# Iteration 40/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (573 n, 1084 e);
# Train Loss: 0.5951, Validation Loss: 0.5979, Validation Accuracy: 0.8596
# Test - coarse accuracy: 0.8362, fine accuracy: 0.9052
#
# Iteration 41/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (571 n, 1055 e);
# Train Loss: 0.6188, Validation Loss: 0.5549, Validation Accuracy: 0.8684
# Test - coarse accuracy: 0.8696, fine accuracy: 0.8854
#
# Iteration 42/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (581 n, 1065 e);
# Train Loss: 0.5450, Validation Loss: 0.5979, Validation Accuracy: 0.8534
# Test - coarse accuracy: 0.8462, fine accuracy: 0.8410
#
# Iteration 43/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (564 n, 1032 e);
# Train Loss: 0.5385, Validation Loss: 0.6227, Validation Accuracy: 0.8214
# Test - coarse accuracy: 0.8421, fine accuracy: 0.8797
#
# Iteration 44/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (568 n, 1044 e);
# Train Loss: 0.5968, Validation Loss: 0.6444, Validation Accuracy: 0.8584
# Test - coarse accuracy: 0.8783, fine accuracy: 0.9012
#
# Iteration 45/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (574 n, 1029 e);
# Train Loss: 0.5851, Validation Loss: 0.5482, Validation Accuracy: 0.8772
# Test - coarse accuracy: 0.9138, fine accuracy: 0.9138
#
# Iteration 46/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (561 n, 998 e);
# Train Loss: 0.5616, Validation Loss: 0.5194, Validation Accuracy: 0.8661
# Test - coarse accuracy: 0.9027, fine accuracy: 0.9174
#
# Iteration 47/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (578 n, 1043 e);
# Train Loss: 0.5597, Validation Loss: 0.4643, Validation Accuracy: 0.8609
# Test - coarse accuracy: 0.9316, fine accuracy: 0.9227
#
# Iteration 48/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (569 n, 1042 e);
# Train Loss: 0.5204, Validation Loss: 0.5738, Validation Accuracy: 0.8584
# Test - coarse accuracy: 0.8609, fine accuracy: 0.9060
#
# Iteration 49/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (576 n, 1045 e);
# Train Loss: 0.5039, Validation Loss: 0.5008, Validation Accuracy: 0.8783
# Test - coarse accuracy: 0.8707, fine accuracy: 0.9113
#
# Iteration 50/50
# Coarsening: variation_edges (2708 n, 5278 e) -> (572 n, 1034 e);
# Train Loss: 0.5250, Validation Loss: 0.4894, Validation Accuracy: 0.8860
# Test - coarse accuracy: 0.8957, fine accuracy: 0.9013

# %% [markdown]
# ## plot data

# %%
methods = ['variation_neighborhoods', 'variation_edges']
ratios = [.5, .8, .9, .95]
thresholds = [0.50, 0.65, 0.75, 0.85]
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray']

def plot_accuracy_coarse_fine(ycrs, yfine):
    plt.figure(figsize=(10, 5))
    plt.plot(ycrs, label='Coarse Accuracy', color='tab:blue')
    plt.plot(yfine, label='Fine Accuracy', linestyle=':', color='tab:blue')
    plt.legend()
    plt.xlabel('Iteration')
    plt.ylabel('Accuracy')
    plt.title('Coarse vs Fine Accuracy over Iterations')
    plt.tight_layout()
    plt.show()
    # plt.savefig('saves/iterative_custom_loss_accuracy.pdf')

# plot graphs one each independently
# for method, ratio, threshold in product(methods, ratios, thresholds):
#     name = f"data_gnn_CoarseningAwareLoss_threshold_{threshold*100:.0f}_{method}_ratio_{ratio*100:.0f}.npy"
#     data = np.load(f"saves/{name}", allow_pickle=True).item()
#     print(data['description'])
#     # plot_training_curves(data['ylosst'], data['ylossv'], data['valacc'])
#     plot_accuracy_coarse_fine(data['ycrs'], data['yfine'])
    
# same ratio and method in the same graph
for method, ratio in product(methods, ratios):
    print(f"Method: {method}, Ratio: {ratio}")
    plt.figure(figsize=(10, 5))
    for idx, threshold in enumerate(thresholds):
        name = f"data_gnn_CoarseningAwareLoss_threshold_{threshold*100:.0f}_{method}_ratio_{ratio*100:.0f}.npy"
        data = np.load(f"saves/{name}", allow_pickle=True).item()
        width = 2 if idx == len(thresholds) - 1 else 1
        plt.plot(data['ycrs'], label=f'Coarse {threshold*100:.0f}%', color=colors[idx], linewidth=width)
        plt.plot(data['yfine'], linestyle=':', label=f'Fine {threshold*100:.0f}%', color=colors[idx], linewidth=width)
    plt.xlabel('Iteration')
    plt.ylabel('Accuracy')
    plt.title('Coarse vs Fine Accuracy over Iterations')
    plt.tight_layout()
    plt.legend()
    plt.show()
# Out:
# Method: variation_neighborhoods, Ratio: 0.5
# Method: variation_neighborhoods, Ratio: 0.8
# Method: variation_neighborhoods, Ratio: 0.9
# Method: variation_neighborhoods, Ratio: 0.95
# Method: variation_edges, Ratio: 0.5
# Method: variation_edges, Ratio: 0.8
# Method: variation_edges, Ratio: 0.9
# Method: variation_edges, Ratio: 0.95
