# %% [markdown]
# # Local Variation + GNN iterative and custom Loss

# %% [markdown]
# ## Import

# %%
import os
import sys
import random
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# pygsp
from pygsp import graphs

# scipy
import scipy as sp

# torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# torch geometric
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.utils import to_undirected

# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics.pairwise import cosine_similarity


# graph coarsening - Loukas 2020
from graphcoarsening.graph_coarsening.coarsening_utils import *
from graphcoarsening.graph_coarsening.graph_utils import *

# datasets
data_path = os.path.abspath(os.path.join("..", "data"))
if data_path not in sys.path:
    sys.path.append(data_path)
from cora.load_cora import load_cora_dataset

# plot
import matplotlib.pyplot as plt

# utils
from utils.split_dataset import *
from utils.visualization import *


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

torch.manual_seed(1)
np.random.seed(1)
# Out:
# Using device: cuda

# %% [markdown]
# ## Global data
#
# - `NODE_IDS`: list of nodes ids
# - `FEATURES`: (N x D) matrix of features for each node
# - `LABELS`: (N) list of true labels for each node
# - `EDGES_IDX`: (M, 2) matrix of edges
# - `IDX_MAP`: dict mapping original node IDs to index

# %%
# load dataset and gloa
NODE_IDS, FEATURES, LABELS, EDGES_IDX, IDX_MAP = load_cora_dataset(log_info=False)
LABELS_ENCODED = LabelEncoder().fit_transform(LABELS)

# %% [markdown]
# ## General functions

# %% [markdown]
# ### Create PyGSP Graph

# %%
def create_pygsp_graph(edges, num_nodes) -> graphs.Graph: 
    # adjacency matrix
    adj_matrix = sp.sparse.coo_matrix(
        (np.ones(len(edges)),
        (edges[:, 0], edges[:, 1])), 
        shape=(num_nodes, num_nodes)
    )
    adj_matrix = adj_matrix + adj_matrix.T
    adj_matrix.data = np.ones(len(adj_matrix.data))

    # pygsp graph
    G = graphs.Graph(adj_matrix)
    G.compute_laplacian()
    G.set_coordinates()
    
    return G

# %% [markdown]
# ### Apply coarsening by Loukas

# %%
def apply_graph_coarsening(G: graphs.Graph, X=None, method='variation_neighborhoods', ratio=0.5, K=3, log_info=False):
    """
    Output:
      - C: coarsening matrix (n, N)
      - Gc: coarsened graph (n, n)
      - Call: all coarsened graphs (levels, n_l, N)
      - Gall: all original graphs (levels, n_l, n_l)
    """
    
    available_methods = ['variation_neighborhoods', 'variation_edges', 'heavy_edge', 'algebraic_JC', 'kron'] 
    if method not in available_methods:
        raise ValueError(f"Unknown coarsening method: {method}. Method must be one of {available_methods}.")
    
    C, Gc, Call, Gall = coarsen(G, X=X, K=K, method=method, r=ratio)

    if log_info:
        print(f"Coarsening: {method} ", end='')
        print(f"({G.N} n, {G.Ne} e) -> ({Gc.N} n, {Gc.Ne} e); ")
    
    return C, Gc, Call, Gall

# %% [markdown]
# ### Get coarsened data from Coarsening matrix C

# %%
def get_coarsened_edges_and_features(C: list, Gc: graphs.Graph, features):
    """
    Coarsen edges and features based on the coarsening matrix C;
    the feature matrix (N x D) is made by summing up features from nodes that are coarsened into the same supernode.

    Output:
      - Gc: coarsened edges index (num_edges, 2)
      - features_coarsened: coarsened features (num_nodes_coarsened, num_features)
    """

    idx_map = {} # map fine node -> coarse node 
    for supernode, node in zip(*C.nonzero()):
        idx_map[node] = supernode
        
    # features coarsened
    features_coarsened = C @ features
    
    # edges coarsened
    edges_idx_coarsened = np.array(Gc.get_edge_list()[:2]).T

    return edges_idx_coarsened, features_coarsened


def get_coarsened_edges_features_labels(C: list, Gc: graphs.Graph, features, labels, priority_label=0):
    """
    Coarsen edges and features based on the coarsening matrix C;
    the feature matrix (N x D) is made by summing up features from nodes that are coarsened into the same supernode.

    Output:
      - edges_idx_coarsened: coarsened edges index (num_edges, 2)
      - features_coarsened: coarsened features (num_nodes_coarsened, num_features)
      - labels_coarsened: coarsened labels (num_nodes_coarsened,)
    """

    idx_map = {} # map fine node -> coarse node 
    for supernode, node in zip(*C.nonzero()):
        idx_map[node] = supernode
        
    # features coarsened
    features_coarsened = C @ features

    # edges coarsened
    edges_idx_coarsened = np.array(Gc.get_edge_list()[:2]).T

    # labels coarsened
    num_classes = len(np.unique(labels))
    all_labels = np.zeros((C.shape[0], num_classes), dtype=np.float32)
    for supernode, node in zip(*C.nonzero()):
        all_labels[supernode, labels[node]] += 1

    labels_coarsened = np.zeros(C.shape[0], dtype=np.int64)
    for supernode in range(C.shape[0]):
        mx = np.argmax(all_labels[supernode])
        priority_count = all_labels[supernode, priority_label]
        if priority_count >= mx:
            labels_coarsened[supernode] = priority_label
        else: 
            labels_coarsened[supernode] = mx

    return edges_idx_coarsened, features_coarsened, labels_coarsened

# %% [markdown]
# ## GNN

# %% [markdown]
# ### model and training function

# %%
class GCN(nn.Module):
    def __init__(self, nfeat, nhid, nclass, dropout=.5):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(nfeat, nhid)
        self.conv2 = GCNConv(nhid, nclass)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)
    
    def get_embeddings(self, x, edge_index):
        x = x.to(next(self.parameters()).device)  # send x to the model's device
        edge_index = edge_index.to(x.device) 
        x = F.relu(self.conv1(x, edge_index))
        return x

class CoarseningAwareLoss(nn.Module):
    def __init__(self, coarse_weight: float = 1.0):
        """
        Args:
          coarse_weight: weight for the coarsening loss term.
        """
        super().__init__()
        self.coarse_weight = coarse_weight
        self.class_loss = nn.NLLLoss()


    def forward(self,
                output: torch.Tensor,
                embeddings: torch.Tensor,
                labels: torch.Tensor,
                coarsening_matrix: torch.Tensor,
                train_idx: torch.Tensor):
        """
        output: [N, C] log-probabilities (log_softmax).
        embeddings: [N, D] raw features from model.get_embeddings().
        labels: [N] ground-truth class labels.
        coarsening_matrix: [Nc, N] coarsening matrix.
        train_idx: indices of coarsened nodes used for classification loss.
        """
        device = output.device
        N = embeddings.shape[0]

        # 1. Classification loss
        loss_cls = self.class_loss(output[train_idx], labels[train_idx])

        # 2. Embedding normalization
        embeddings_norm = F.normalize(embeddings, p=2, dim=1)

        with torch.no_grad():
            supernodes = torch.zeros(N, dtype=torch.long, device=device)
            for i, j in zip(*coarsening_matrix.nonzero()):
                supernodes[j] = i


        loss_coarse = torch.tensor(0.0, device=device)
        count = 0

        n_sample = 500
        for _ in range(n_sample):
            i, j = random.sample(range(N), 2)
            emb_i = embeddings_norm[i]
            emb_j = embeddings_norm[j]
            sim = F.cosine_similarity(emb_i.unsqueeze(0), emb_j.unsqueeze(0)).squeeze()

            if supernodes[i] == supernodes[j]:
                loss_coarse += 1 - sim
            else:
                loss_coarse += sim
            count += 1

        loss_coarse = loss_coarse / count if count > 0 else torch.tensor(0.0, device=device)
        return loss_cls + self.coarse_weight * loss_coarse

# %%
def create_pyg_data(features, edges_idx, labels) -> Data:
    x = torch.FloatTensor(features.astype(np.float32))
    y = torch.LongTensor(labels)
    edge_index = torch.LongTensor(edges_idx.T)  # expects (2, num_edges)
    edge_index = to_undirected(edge_index)
        
    return Data(x=x, edge_index=edge_index, y=y)

def train_gnn_1_epoch(model: nn.Module, optimizer: optim.Optimizer, criterion: nn.Module, data: Data, embeddings, coarsening_matrix, train_idx: list, val_idx: list):
    """
    Output:
        - train_loss
        - val_loss
        - val_accuracy
    """
    
    data = data.to(next(model.parameters()).device)
    
    model.train()
    optimizer.zero_grad()
    
    output = model(data.x, data.edge_index)
    # embeddings = model.get_embeddings(data.x, data.edge_index)

    # train
    loss = criterion(output, embeddings, data.y, coarsening_matrix, train_idx)
    loss.backward()
    optimizer.step()
    
    # validate
    model.eval()
    with torch.no_grad():
        output = model(data.x, data.edge_index)
        # embeddings = model.get_embeddings(data.x, data.edge_index)

        loss_val = criterion(output, embeddings, data.y, coarsening_matrix, val_idx)
        pred_val = output[val_idx].max(1)[1]
        acc_val = accuracy_score(data.y[val_idx].cpu().numpy(), pred_val.cpu().numpy())

    
    return loss.item(), loss_val.item(), acc_val

def evaluate_model(model: nn.Module, data: Data, test_idx, log_info=True):
    """Evaluate the model on test set."""
    model.eval()
    data = data.to(next(model.parameters()).device)
    
    with torch.no_grad():
        output = model(data.x, data.edge_index)
        pred_test = output[test_idx].max(1)[1]
        acc_test = accuracy_score(data.y[test_idx].cpu().numpy(), pred_test.cpu().numpy())
        
        if log_info:
            print(f'\nTest Accuracy: {acc_test:.4f}')
            print('\nClassification Report:')
            print(classification_report(
                data.y[test_idx].cpu().numpy(), pred_test.cpu().numpy())
            )

    return acc_test, pred_test

# %% [markdown]
# ## `Coarsen - GNN and Loss`
#
# **workflow:**
# ```latex
# 1. Train GNN on full graph to initialize weights
# 2. Iterate:
#     1. generate embeddings of all nodes from GNN(A, X)
#     2. coarsen the graph using embeddings as node features
#     3. Train GNN on coarsened nodes
#         - loss is coarsening-aware
# ```

# %%
# model
nnodes = NODE_IDS.shape[0]  # 2708
nfeat = FEATURES.shape[1]  # 1433
nhid = 128
nclass = len(np.unique(LABELS_ENCODED))  # 7
dropout = 0.1
model = GCN(nfeat=nfeat, nhid=nhid, nclass=nclass, dropout=dropout).to(device)

# criterion
criterion = CoarseningAwareLoss()

# train data
wd = 5e-4
lr = 0.01
epochs = 50
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
data = create_pyg_data(FEATURES, EDGES_IDX, LABELS_ENCODED)

ratio = 0.8
method = 'variation_neighborhoods'
x, ycrs, yfine, ylosst, ylossv, valacc = [], [], [], [], [], []
for epoch in range(epochs):

    print(f"Iteration {epoch + 1:02d}/{epochs}")

    # get embeddings from the GNN
    embeddings = model.get_embeddings(data.x, data.edge_index)

    # coarsen the graph using embeddings as features
    G = create_pygsp_graph(EDGES_IDX, data.num_nodes)
    C, Gc, Call, Gall = apply_graph_coarsening(
        G, X=embeddings, method='variation_neighborhoods', ratio=0.8, K=50, log_info=True
    )

    # train the GNN on the coarsened graph
    edges_idx_c, feat_c, labels_C = get_coarsened_edges_features_labels(
        C, Gc, FEATURES, LABELS_ENCODED, priority_label=0
    )
    data_c = create_pyg_data(feat_c, edges_idx_c, labels_C)
    train_idx_c, val_idx_c, test_idx_c = create_train_val_test_split(data_c.num_nodes)
    train_idx_c = torch.LongTensor(train_idx_c).to(device)
    val_idx_c = torch.LongTensor(val_idx_c).to(device)
    test_idx_c = torch.LongTensor(test_idx_c).to(device)
    train_loss, validation_loss, validation_accuracy = train_gnn_1_epoch(
        model, optimizer, criterion, data_c, embeddings, C, train_idx_c, val_idx_c
    )

    print(f"Train Loss: {train_loss:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}")

    # evaluate the model on the coarsened graph
    acc_test_c, pred_test_c = evaluate_model(model, data_c, test_idx_c, log_info=False)

    # evaluate on original (fine) graph
    pred_fine = np.array([-1 for _ in range(NODE_IDS.shape[0])], dtype=np.int64)
    tot = 0
    for idx in range(len(test_idx_c)):
        test_supernode = test_idx_c[idx]
        for fine_node in C.getrow(test_supernode).nonzero()[1]:
            pred_fine[fine_node] = pred_test_c[idx]
            tot += 1

    sm = sum(pred_fine == LABELS_ENCODED)
    accuracy_fine = sm / tot

    print(f"Test - coarse accuracy: {acc_test_c:.4f}, fine accuracy: {accuracy_fine:.4f}\n")

    # ploting data
    x.append(epoch + 1)
    ycrs.append(acc_test_c)
    yfine.append(accuracy_fine)
    ylosst.append(train_loss)
    ylossv.append(validation_loss)
    valacc.append(validation_accuracy)

np.save(f'saves/data_iterative_custom_loss_feat_t075.npy', {
       'x': x,
       'ycrs': ycrs,
       'yfine': yfine,
       'ylosst': ylosst,
       'ylossv': ylossv,
       'valacc': valacc,
       'description': f'Data obtained using: {ratio=}, {method=}, CoarseningAwareLoss()'
    })
# Out:
# Iteration 01/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1547 n, 3103 e);
# Train Loss: 2.3583, Validation Loss: 2.1960, Validation Accuracy: 0.4369
# Test - coarse accuracy: 0.4484, fine accuracy: 0.4781
#
# Iteration 02/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (955 n, 1732 e);
# Train Loss: 2.2922, Validation Loss: 2.2204, Validation Accuracy: 0.5969
# Test - coarse accuracy: 0.6021, fine accuracy: 0.4626
#
# Iteration 03/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (1003 n, 1839 e);
# Train Loss: 2.0875, Validation Loss: 2.0604, Validation Accuracy: 0.7350
# Test - coarse accuracy: 0.7376, fine accuracy: 0.6703
#
# Iteration 04/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (970 n, 1759 e);
# Train Loss: 1.9906, Validation Loss: 1.9104, Validation Accuracy: 0.7113
# Test - coarse accuracy: 0.7423, fine accuracy: 0.6765
#
# Iteration 05/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (937 n, 1699 e);
# Train Loss: 1.8820, Validation Loss: 1.7856, Validation Accuracy: 0.7326
# Test - coarse accuracy: 0.7500, fine accuracy: 0.8474
#
# Iteration 06/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (885 n, 1559 e);
# Train Loss: 1.7884, Validation Loss: 1.6651, Validation Accuracy: 0.7514
# Test - coarse accuracy: 0.6441, fine accuracy: 0.6921
#
# Iteration 07/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (810 n, 1385 e);
# Train Loss: 1.6796, Validation Loss: 1.5460, Validation Accuracy: 0.7222
# Test - coarse accuracy: 0.7099, fine accuracy: 0.6421
#
# Iteration 08/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (769 n, 1404 e);
# Train Loss: 1.5645, Validation Loss: 1.4629, Validation Accuracy: 0.7255
# Test - coarse accuracy: 0.6839, fine accuracy: 0.7232
#
# Iteration 09/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (698 n, 1177 e);
# Train Loss: 1.4601, Validation Loss: 1.3111, Validation Accuracy: 0.7410
# Test - coarse accuracy: 0.7376, fine accuracy: 0.7358
#
# Iteration 10/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (657 n, 1096 e);
# Train Loss: 1.3766, Validation Loss: 1.3871, Validation Accuracy: 0.6870
# Test - coarse accuracy: 0.6439, fine accuracy: 0.6858
#
# Iteration 11/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (665 n, 1029 e);
# Train Loss: 1.2424, Validation Loss: 1.1479, Validation Accuracy: 0.7895
# Test - coarse accuracy: 0.7444, fine accuracy: 0.5000
#
# Iteration 12/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (650 n, 1052 e);
# Train Loss: 1.3105, Validation Loss: 1.1398, Validation Accuracy: 0.7615
# Test - coarse accuracy: 0.7692, fine accuracy: 0.6591
#
# Iteration 13/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (586 n, 919 e);
# Train Loss: 1.0575, Validation Loss: 1.1459, Validation Accuracy: 0.7521
# Test - coarse accuracy: 0.7797, fine accuracy: 0.7931
#
# Iteration 14/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (542 n, 843 e);
# Train Loss: 1.1145, Validation Loss: 1.1924, Validation Accuracy: 0.7407
# Test - coarse accuracy: 0.7615, fine accuracy: 0.6250
#
# Iteration 15/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (603 n, 951 e);
# Train Loss: 1.0644, Validation Loss: 1.0299, Validation Accuracy: 0.7583
# Test - coarse accuracy: 0.8115, fine accuracy: 0.7492
#
# Iteration 16/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (568 n, 870 e);
# Train Loss: 1.0919, Validation Loss: 1.0610, Validation Accuracy: 0.7699
# Test - coarse accuracy: 0.7391, fine accuracy: 0.3454
#
# Iteration 17/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (651 n, 1166 e);
# Train Loss: 0.9400, Validation Loss: 1.0465, Validation Accuracy: 0.8231
# Test - coarse accuracy: 0.8779, fine accuracy: 0.8597
#
# Iteration 18/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (553 n, 896 e);
# Train Loss: 0.9539, Validation Loss: 0.9735, Validation Accuracy: 0.8182
# Test - coarse accuracy: 0.8393, fine accuracy: 0.2704
#
# Iteration 19/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (590 n, 984 e);
# Train Loss: 0.8878, Validation Loss: 0.9133, Validation Accuracy: 0.7881
# Test - coarse accuracy: 0.7797, fine accuracy: 0.4922
#
# Iteration 20/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (576 n, 936 e);
# Train Loss: 0.9015, Validation Loss: 0.8849, Validation Accuracy: 0.8174
# Test - coarse accuracy: 0.7759, fine accuracy: 0.8333
#
# Iteration 21/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (544 n, 857 e);
# Train Loss: 1.0265, Validation Loss: 0.8165, Validation Accuracy: 0.8704
# Test - coarse accuracy: 0.8091, fine accuracy: 0.8519
#
# Iteration 22/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (610 n, 1008 e);
# Train Loss: 0.7498, Validation Loss: 1.0315, Validation Accuracy: 0.8115
# Test - coarse accuracy: 0.7869, fine accuracy: 0.7944
#
# Iteration 23/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (576 n, 937 e);
# Train Loss: 0.8333, Validation Loss: 0.8627, Validation Accuracy: 0.8348
# Test - coarse accuracy: 0.8879, fine accuracy: 0.8857
#
# Iteration 24/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (664 n, 1106 e);
# Train Loss: 0.7509, Validation Loss: 0.7422, Validation Accuracy: 0.8561
# Test - coarse accuracy: 0.7985, fine accuracy: 0.8784
#
# Iteration 25/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (667 n, 1080 e);
# Train Loss: 0.8075, Validation Loss: 0.8692, Validation Accuracy: 0.8346
# Test - coarse accuracy: 0.8731, fine accuracy: 0.5025
#
# Iteration 26/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (639 n, 995 e);
# Train Loss: 0.7199, Validation Loss: 0.7677, Validation Accuracy: 0.8504
# Test - coarse accuracy: 0.7907, fine accuracy: 0.7018
#
# Iteration 27/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (654 n, 1037 e);
# Train Loss: 0.7921, Validation Loss: 0.5965, Validation Accuracy: 0.9077
# Test - coarse accuracy: 0.8485, fine accuracy: 0.8367
#
# Iteration 28/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (649 n, 1050 e);
# Train Loss: 0.7310, Validation Loss: 0.6849, Validation Accuracy: 0.8837
# Test - coarse accuracy: 0.8626, fine accuracy: 0.8536
#
# Iteration 29/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (658 n, 1052 e);
# Train Loss: 0.6942, Validation Loss: 0.6262, Validation Accuracy: 0.8779
# Test - coarse accuracy: 0.8571, fine accuracy: 0.5846
#
# Iteration 30/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (701 n, 1233 e);
# Train Loss: 0.6835, Validation Loss: 0.6575, Validation Accuracy: 0.8500
# Test - coarse accuracy: 0.8156, fine accuracy: 0.8837
#
# Iteration 31/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (649 n, 1154 e);
# Train Loss: 0.7268, Validation Loss: 0.7118, Validation Accuracy: 0.8450
# Test - coarse accuracy: 0.8626, fine accuracy: 0.8523
#
# Iteration 32/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (675 n, 1204 e);
# Train Loss: 0.7161, Validation Loss: 0.6509, Validation Accuracy: 0.8444
# Test - coarse accuracy: 0.8148, fine accuracy: 0.8216
#
# Iteration 33/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (705 n, 1276 e);
# Train Loss: 0.7382, Validation Loss: 0.6490, Validation Accuracy: 0.9149
# Test - coarse accuracy: 0.8936, fine accuracy: 0.8344
#
# Iteration 34/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (692 n, 1236 e);
# Train Loss: 0.6077, Validation Loss: 0.6708, Validation Accuracy: 0.8623
# Test - coarse accuracy: 0.8201, fine accuracy: 0.7150
#
# Iteration 35/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (700 n, 1241 e);
# Train Loss: 0.5730, Validation Loss: 0.8111, Validation Accuracy: 0.8429
# Test - coarse accuracy: 0.8714, fine accuracy: 0.8000
#
# Iteration 36/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (704 n, 1280 e);
# Train Loss: 0.5585, Validation Loss: 0.8396, Validation Accuracy: 0.8214
# Test - coarse accuracy: 0.8451, fine accuracy: 0.8436
#
# Iteration 37/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (702 n, 1280 e);
# Train Loss: 0.6725, Validation Loss: 0.6232, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.8652, fine accuracy: 0.8750
#
# Iteration 38/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (674 n, 1226 e);
# Train Loss: 0.6481, Validation Loss: 0.6411, Validation Accuracy: 0.8582
# Test - coarse accuracy: 0.8603, fine accuracy: 0.8115
#
# Iteration 39/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (668 n, 1164 e);
# Train Loss: 0.6349, Validation Loss: 0.5362, Validation Accuracy: 0.9098
# Test - coarse accuracy: 0.8815, fine accuracy: 0.9090
#
# Iteration 40/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (670 n, 1228 e);
# Train Loss: 0.6547, Validation Loss: 0.5283, Validation Accuracy: 0.8955
# Test - coarse accuracy: 0.8955, fine accuracy: 0.8173
#
# Iteration 41/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (684 n, 1228 e);
# Train Loss: 0.6158, Validation Loss: 0.5717, Validation Accuracy: 0.9044
# Test - coarse accuracy: 0.8768, fine accuracy: 0.6705
#
# Iteration 42/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (685 n, 1255 e);
# Train Loss: 0.5678, Validation Loss: 0.5460, Validation Accuracy: 0.8978
# Test - coarse accuracy: 0.8686, fine accuracy: 0.9159
#
# Iteration 43/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (663 n, 1130 e);
# Train Loss: 0.6203, Validation Loss: 0.5443, Validation Accuracy: 0.8864
# Test - coarse accuracy: 0.8881, fine accuracy: 0.8985
#
# Iteration 44/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (675 n, 1272 e);
# Train Loss: 0.5527, Validation Loss: 0.5217, Validation Accuracy: 0.8741
# Test - coarse accuracy: 0.8963, fine accuracy: 0.8880
#
# Iteration 45/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (684 n, 1252 e);
# Train Loss: 0.5774, Validation Loss: 0.5926, Validation Accuracy: 0.8750
# Test - coarse accuracy: 0.8623, fine accuracy: 0.8473
#
# Iteration 46/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (692 n, 1227 e);
# Train Loss: 0.5632, Validation Loss: 0.5119, Validation Accuracy: 0.8986
# Test - coarse accuracy: 0.8993, fine accuracy: 0.8622
#
# Iteration 47/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (705 n, 1233 e);
# Train Loss: 0.5181, Validation Loss: 0.4948, Validation Accuracy: 0.8936
# Test - coarse accuracy: 0.9149, fine accuracy: 0.5864
#
# Iteration 48/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (720 n, 1338 e);
# Train Loss: 0.5157, Validation Loss: 0.6147, Validation Accuracy: 0.9097
# Test - coarse accuracy: 0.8403, fine accuracy: 0.8433
#
# Iteration 49/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (696 n, 1245 e);
# Train Loss: 0.5483, Validation Loss: 0.4699, Validation Accuracy: 0.8777
# Test - coarse accuracy: 0.8571, fine accuracy: 0.8503
#
# Iteration 50/50
# Coarsening: variation_neighborhoods (2708 n, 5278 e) -> (652 n, 1132 e);
# Train Loss: 0.5849, Validation Loss: 0.4994, Validation Accuracy: 0.9000
# Test - coarse accuracy: 0.8626, fine accuracy: 0.8705

# %%
data = np.load(f'saves/data_iterative_custom_loss_feat_t075.npy', allow_pickle=True).item()
plot_training_curves(data['ylosst'], data['ylossv'], data['valacc'])

plt.figure(figsize=(10, 5))
plt.plot(data['x'], data['ycrs'], label='Coarse Accuracy', color='tab:blue')
plt.plot(data['x'], data['yfine'], label='Fine Accuracy', linestyle=':', color='tab:blue')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Coarse vs Fine Accuracy over Iterations')
plt.tight_layout()
plt.show()
# plt.savefig('saves/iterative_custom_loss_accuracy.pdf')
